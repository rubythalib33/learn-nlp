# %% [markdown]
# <a href="https://colab.research.google.com/github/rubythalib33/learn-nlp/blob/main/01Basic_Chatbot/Python_Chatbot_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# source: https://www.projectpro.io/article/python-chatbot-project-learn-to-build-a-chatbot-from-scratch/429#toc-6

# %%
data_root = "drive/MyDrive/chatbot/"

# %%
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
data_file = open(data_root+"/intents.json").read()
data = json.loads(data_file)

# %%
# Step-4: Identifying Feature and Target for the NLP Model
words = []
classes = []
data_X = []
data_Y = []

for intent in data["intents"]:
  for pattern in intent['patterns']:
    tokens = nltk.word_tokenize(pattern)
    words.extend(tokens)
    data_X.append(pattern)
    data_Y.append(intent['tag'])
  
  if intent["tag"] not in classes:
    classes.append(intent["tag"])

# %%
lemmatizer = WordNetLemmatizer()

# %%
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))
classes = sorted(set(classes))

# %%
#Step-5: Making the data Machine-friendly
training = []
out_empty = [0]*len(classes)
for idx, doc in enumerate(data_X):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)
  
  output_row = list(out_empty)
  output_row[classes.index(data_Y[idx])] = 1

  training.append([bow,output_row] )

random.shuffle(training)
training = np.array(training, dtype=object)
train_x = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network model

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(classes), activation="softmax"))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
model.fit(x=train_x, y=train_y, epochs=150, verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               30592
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 44)                2860
#
# =================================================================
# Total params: 41,708
# Trainable params: 41,708
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 4/4 [==============================] - 1s 5ms/step - loss: 3.8561 - accuracy: 0.0248
# Epoch 2/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.8004 - accuracy: 0.0165
# Epoch 3/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.7631 - accuracy: 0.0331
# Epoch 4/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.7826 - accuracy: 0.0165
# Epoch 5/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.7411 - accuracy: 0.0165
# Epoch 6/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.6969 - accuracy: 0.0579
# Epoch 7/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.6872 - accuracy: 0.0661
# Epoch 8/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.6312 - accuracy: 0.1157
# Epoch 9/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.6111 - accuracy: 0.0992
# Epoch 10/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5982 - accuracy: 0.1074
# Epoch 11/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.6002 - accuracy: 0.0744
# Epoch 12/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5616 - accuracy: 0.1322
# Epoch 13/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.5032 - accuracy: 0.1818
# Epoch 14/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.4764 - accuracy: 0.1736
# Epoch 15/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.4297 - accuracy: 0.2149
# Epoch 16/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.4375 - accuracy: 0.1983
# Epoch 17/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.3761 - accuracy: 0.1818
# Epoch 18/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.3411 - accuracy: 0.1983
# Epoch 19/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.2940 - accuracy: 0.2066
# Epoch 20/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.2109 - accuracy: 0.2479
# Epoch 21/150
# 4/4 [==============================] - 0s 4ms/step - loss: 3.1529 - accuracy: 0.2727
# Epoch 22/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.1449 - accuracy: 0.2645
# Epoch 23/150
# 4/4 [==============================] - 0s 7ms/step - loss: 3.0590 - accuracy: 0.2149
# Epoch 24/150
# 4/4 [==============================] - 0s 5ms/step - loss: 3.1030 - accuracy: 0.1983
# Epoch 25/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.9387 - accuracy: 0.2562
# Epoch 26/150
# 4/4 [==============================] - 0s 6ms/step - loss: 2.9391 - accuracy: 0.2975
# Epoch 27/150
# 4/4 [==============================] - 0s 7ms/step - loss: 2.9233 - accuracy: 0.3058
# Epoch 28/150
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7903 - accuracy: 0.3140
# Epoch 29/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.8334 - accuracy: 0.2645
# Epoch 30/150
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6747 - accuracy: 0.3636
# Epoch 31/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7161 - accuracy: 0.3967
# Epoch 32/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6319 - accuracy: 0.3719
# Epoch 33/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5479 - accuracy: 0.4215
# Epoch 34/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4653 - accuracy: 0.3884
# Epoch 35/150
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5291 - accuracy: 0.3554
# Epoch 36/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4096 - accuracy: 0.4463
# Epoch 37/150
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3146 - accuracy: 0.4545
# Epoch 38/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2374 - accuracy: 0.4959
# Epoch 39/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2168 - accuracy: 0.4380
# Epoch 40/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1137 - accuracy: 0.4380
# Epoch 41/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1117 - accuracy: 0.5041
# Epoch 42/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0811 - accuracy: 0.5207
# Epoch 43/150
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2046 - accuracy: 0.4132
# Epoch 44/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9844 - accuracy: 0.5372
# Epoch 45/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9116 - accuracy: 0.5537
# Epoch 46/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.8841 - accuracy: 0.6446
# Epoch 47/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8399 - accuracy: 0.5455
# Epoch 48/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9428 - accuracy: 0.5537
# Epoch 49/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6716 - accuracy: 0.6694
# Epoch 50/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7533 - accuracy: 0.5372
# Epoch 51/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6960 - accuracy: 0.5537
# Epoch 52/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6977 - accuracy: 0.6281
# Epoch 53/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6351 - accuracy: 0.5537
# Epoch 54/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5446 - accuracy: 0.6364
# Epoch 55/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.6557 - accuracy: 0.5537
# Epoch 56/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.5402 - accuracy: 0.6694
# Epoch 57/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6247 - accuracy: 0.6033
# Epoch 58/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4512 - accuracy: 0.6116
# Epoch 59/150
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3557 - accuracy: 0.7438
# Epoch 60/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3383 - accuracy: 0.6942
# Epoch 61/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3820 - accuracy: 0.6777
# Epoch 62/150
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2726 - accuracy: 0.6942
# Epoch 63/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2728 - accuracy: 0.6942
# Epoch 64/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2818 - accuracy: 0.6777
# Epoch 65/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3146 - accuracy: 0.6446
# Epoch 66/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1776 - accuracy: 0.7355
# Epoch 67/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3028 - accuracy: 0.6612
# Epoch 68/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1420 - accuracy: 0.6694
# Epoch 69/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1381 - accuracy: 0.7025
# Epoch 70/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1816 - accuracy: 0.6942
# Epoch 71/150
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1498 - accuracy: 0.7273
# Epoch 72/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2041 - accuracy: 0.7025
# Epoch 73/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0033 - accuracy: 0.7521
# Epoch 74/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9987 - accuracy: 0.7934
# Epoch 75/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9787 - accuracy: 0.7438
# Epoch 76/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0373 - accuracy: 0.7355
# Epoch 77/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9684 - accuracy: 0.7769
# Epoch 78/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8682 - accuracy: 0.8678
# Epoch 79/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9119 - accuracy: 0.7190
# Epoch 80/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9118 - accuracy: 0.7769
# Epoch 81/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0154 - accuracy: 0.7438
# Epoch 82/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9617 - accuracy: 0.7769
# Epoch 83/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9541 - accuracy: 0.7438
# Epoch 84/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8181 - accuracy: 0.7769
# Epoch 85/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9136 - accuracy: 0.7769
# Epoch 86/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9143 - accuracy: 0.7851
# Epoch 87/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9475 - accuracy: 0.7438
# Epoch 88/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9232 - accuracy: 0.7851
# Epoch 89/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8009 - accuracy: 0.8182
# Epoch 90/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8731 - accuracy: 0.7686
# Epoch 91/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8059 - accuracy: 0.7769
# Epoch 92/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8213 - accuracy: 0.7769
# Epoch 93/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7479 - accuracy: 0.8595
# Epoch 94/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7079 - accuracy: 0.7851
# Epoch 95/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7310 - accuracy: 0.8017
# Epoch 96/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7518 - accuracy: 0.7934
# Epoch 97/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7007 - accuracy: 0.8678
# Epoch 98/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6811 - accuracy: 0.8017
# Epoch 99/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7133 - accuracy: 0.8347
# Epoch 100/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6334 - accuracy: 0.8347
# Epoch 101/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6438 - accuracy: 0.8430
# Epoch 102/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6223 - accuracy: 0.8595
# Epoch 103/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6436 - accuracy: 0.8347
# Epoch 104/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7484 - accuracy: 0.7851
# Epoch 105/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6951 - accuracy: 0.8347
# Epoch 106/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5816 - accuracy: 0.8430
# Epoch 107/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4946 - accuracy: 0.9008
# Epoch 108/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5753 - accuracy: 0.8926
# Epoch 109/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6611 - accuracy: 0.8347
# Epoch 110/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5518 - accuracy: 0.8760
# Epoch 111/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7082 - accuracy: 0.8182
# Epoch 112/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6180 - accuracy: 0.8678
# Epoch 113/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5260 - accuracy: 0.8264
# Epoch 114/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7531 - accuracy: 0.8099
# Epoch 115/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5611 - accuracy: 0.8099
# Epoch 116/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5609 - accuracy: 0.8430
# Epoch 117/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5523 - accuracy: 0.9008
# Epoch 118/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5221 - accuracy: 0.8678
# Epoch 119/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5462 - accuracy: 0.8430
# Epoch 120/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5421 - accuracy: 0.8430
# Epoch 121/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4553 - accuracy: 0.8926
# Epoch 122/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5340 - accuracy: 0.8678
# Epoch 123/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4129 - accuracy: 0.9091
# Epoch 124/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5617 - accuracy: 0.8760
# Epoch 125/150
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5225 - accuracy: 0.8512
# Epoch 126/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5212 - accuracy: 0.8595
# Epoch 127/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4992 - accuracy: 0.8678
# Epoch 128/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5627 - accuracy: 0.8512
# Epoch 129/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4888 - accuracy: 0.8760
# Epoch 130/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5060 - accuracy: 0.8512
# Epoch 131/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4922 - accuracy: 0.8843
# Epoch 132/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4356 - accuracy: 0.8760
# Epoch 133/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5174 - accuracy: 0.8843
# Epoch 134/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3779 - accuracy: 0.9174
# Epoch 135/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4047 - accuracy: 0.9008
# Epoch 136/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4377 - accuracy: 0.8843
# Epoch 137/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4338 - accuracy: 0.9174
# Epoch 138/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.8926
# Epoch 139/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5864 - accuracy: 0.8347
# Epoch 140/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4085 - accuracy: 0.8760
# Epoch 141/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5090 - accuracy: 0.8760
# Epoch 142/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4343 - accuracy: 0.8843
# Epoch 143/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4802 - accuracy: 0.8760
# Epoch 144/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4798 - accuracy: 0.8926
# Epoch 145/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5584 - accuracy: 0.8347
# Epoch 146/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4329 - accuracy: 0.9174
# Epoch 147/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4362 - accuracy: 0.9008
# Epoch 148/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4658 - accuracy: 0.8678
# Epoch 149/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4392 - accuracy: 0.9256
# Epoch 150/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4569 - accuracy: 0.9008

# %%
# Step-7: Pre-processing the User’s Input
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(token) for token in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0]*len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_labels(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  tresh = 0.5
  y_pred = [[indx, pred] for indx, pred in enumerate(result) if pred > tresh]
  y_pred.sort(key = lambda x: x[1], reverse=True)
  return_list = [labels[r[0]] for r in y_pred]

  return return_list

def get_response(intents_list, intents_json):
  if len(intents_list) == 0:
    result = "Sorry I don't Understand"
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents:
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break

  return result

# %%
# Step 8 interacting with the chatbot
print("press 0 if you want to exit")
while True:
  message = input()
  if message == "0":
    print("program exit")
    break
  intents = pred_labels(message, words, classes)
  result = get_response(intents, data)
  print(result)
# Out:
# press 0 if you want to exit
# hello
# Hi there, how can I help?
# how are you?
# Sorry I don't Understand
# good morning
# Hi there, how can I help?
# 0
# program exit
